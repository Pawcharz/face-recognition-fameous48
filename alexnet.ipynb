# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

from keras import layers
from keras import regularizers

import re

# %%
from keras import backend as K

keras.utils.set_random_seed(42)

# %%
physical_devices = tf.config.list_physical_devices()
CLASSES = 48
IMAGE_SIZE = 24

print(physical_devices)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.set_visible_devices(physical_devices[1], 'GPU')

# %% [markdown]
# ## Building Dataset

# %% [markdown]
# ### Attributes description
#
# - a1 - face containing flag: (1-with face, 0-without face),
# - a2 - image number in current class (person) beginning from 0,
# - a3 - class (person) number beginning from 0,
# - a4 - sex (0 - woman, 1 - man)
# - a5 - race (0- white, 1 - black, 2 - indian, ...)
# - a6 - age (0 - baby, 1 - young, 2 - middle-age, 3 - old)
# - a7 - binokulars (0 - without, 1 - transparent, 2 - dark)
# - a8 - emotional expression (not state!) (0 - sad, 1 - neutral, 2 - happy)

# %%
def read_file(filename):
  
  with open(filename, 'r') as file:
    lines = file.readlines()
    
    # Remove newLines
    for i, line in enumerate(lines):
      lines[i] = line.replace('\n', '')
    
    # We assume these are integers
    EXAMPLES_NR = int(lines[0])
    PIXELS_NR = int(lines[1])
    
    inputs = list()
    labels = np.zeros(EXAMPLES_NR, dtype=int)
    
    examples_raw = lines[2:EXAMPLES_NR+2]
    
    for i, example_raw in enumerate(examples_raw):
      # Split by spaces (treats multiple as one)
      tokens = re.split('\s+', example_raw)
      
      pixel_values = np.array(tokens[0:PIXELS_NR])
      attributes = tokens[PIXELS_NR:]
      
      pixel_values = np.array(pixel_values, dtype=float)
      pixel_values = pixel_values.reshape([IMAGE_SIZE, IMAGE_SIZE])
      
      inputs.append(pixel_values)
      labels[i] = int(attributes[2])
      
    inputs = np.array(inputs)
  return inputs, labels

# %%
# classes 0-15
X_0, y_0 = read_file('./data/x24x24.txt')
# classes 16-31
X_1, y_1 = read_file('./data/y24x24.txt')
# # classes 32-48
X_2, y_2 = read_file('./data/z24x24.txt')

print(len(X_0), len(y_0))
print(len(X_1), len(y_1))
print(len(X_2), len(y_2))
# Out:
# 2321 2321
# 2208 2208
# 2306 2306

# %%
from sklearn.model_selection import train_test_split

# Concatenate train and test images
X = np.concatenate((X_0, X_1, X_2))
y = np.concatenate((y_0, y_1, y_2))
print(len(X), len(y))

N_TRAIN_EXAMPLES=int(len(X) * 0.8)
N_TEST_EXAMPLES=len(X) - N_TRAIN_EXAMPLES


X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=N_TRAIN_EXAMPLES, test_size=N_TEST_EXAMPLES, random_state=1)

# One-Hot encoding
# Getting dummy variables
y_train_fixed = np.zeros((y_train.shape[0], CLASSES))
# y_valid_fixed = np.zeros((y_valid.shape[0], 10))
y_test_fixed = np.zeros((y_test.shape[0], CLASSES))

for i, value in enumerate(y_train):
  y_train_fixed[i][value] = 1
  
for i, value in enumerate(y_test):
  y_test_fixed[i][value] = 1
# Out:
# 6835 6835

# %%
print(len(X_test))
# Out:
# 1367

# %% [markdown]
# ## Building a model

# %% [markdown]
# I decided to down-scale the alexNet as it was for the long time the SOTA Convolutional Neural Network Architecture
#
# Full AlexNet implementation in keras:
#
# ```py
#   keras.Input(shape=(227, 227, 3)),
#   layers.Conv2D(96, kernel_size=11, strides=4, padding='same', activation="relu"),
#   layers.MaxPooling2D(pool_size=3, strides=2),
#   layers.Conv2D(256, kernel_size=5, padding='same', activation="relu"),
#   layers.MaxPooling2D(pool_size=3, strides=2),
#   layers.Conv2D(384, kernel_size=3, padding='same', activation="relu"),
#   layers.Conv2D(384, kernel_size=3, padding='same', activation="relu"),
#   layers.Conv2D(256, kernel_size=3, padding='same', activation="relu"),
#   layers.MaxPooling2D(pool_size=3, strides=2),
#   layers.Dropout(0.5),
#   layers.Dense(4096, activation="relu"),
#   layers.Dropout(0.5),
#   layers.Dense(4096, activation="relu"),
#   layers.Dense(CLASSES, activation="softmax")
# ```

# %%
from keras import Sequential, Input
from functools import partial

conv_regularizer = regularizers.l2(0.0006)
dense_regularizer = regularizers.l2(0.01)

DefaultConv2D = partial(tf.keras.layers.Conv2D, kernel_size=3, padding="same",
                        activation="relu", kernel_regularizer=conv_regularizer)


model = keras.Sequential(
  [
    Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 1)),
    DefaultConv2D(96),
    layers.MaxPooling2D(pool_size=3, strides=2),

    tf.keras.layers.Dropout(0.3),
    DefaultConv2D(256, kernel_size=5),
    tf.keras.layers.MaxPooling2D(pool_size=3, strides=2),

    tf.keras.layers.Dropout(0.4),
    DefaultConv2D(384),
    tf.keras.layers.Dropout(0.5),
    DefaultConv2D(384),
    tf.keras.layers.MaxPooling2D(pool_size=3, strides=2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.6),
    tf.keras.layers.Dense(384, activation='relu', kernel_regularizer=dense_regularizer),
    tf.keras.layers.Dense(CLASSES, activation='softmax'),
  ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 96)        960
#
#  max_pooling2d (MaxPooling2D  (None, 11, 11, 96)       0
#  )
#
#  dropout (Dropout)           (None, 11, 11, 96)        0
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 256)       614656
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 256)         0
#
#  conv2d_2 (Conv2D)           (None, 5, 5, 384)         885120
#
#  dropout_2 (Dropout)         (None, 5, 5, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 5, 5, 384)         1327488
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 384)        0
#  2D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dropout_3 (Dropout)         (None, 1536)              0
#
#  dense (Dense)               (None, 384)               590208
#
#  dense_1 (Dense)             (None, 48)                18480
#
# =================================================================
# Total params: 3,436,912
# Trainable params: 3,436,912
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import SGD, Adam
from keras.losses import categorical_crossentropy

# optimizer = Adam(learning_rate=0.00025)
optimizer = Adam(learning_rate=0.001)

model.compile(loss=categorical_crossentropy, optimizer=optimizer, metrics=["accuracy"])

# %% [markdown]
# ## Training Preparation

# %%
CHECKPOINT_PATH = 'models/checkpoints/famous48_test_model_v2_best.keras'

# %%
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
  filepath=CHECKPOINT_PATH,
  save_weights_only=False,
  monitor='val_accuracy',
  mode='max',
  save_best_only=True,
)

# %%
# %%time
batch_size = 200
epochs = 250

history = model.fit(
  X_train, y_train_fixed,
  batch_size=batch_size,
  epochs=epochs,
  validation_split=0.2,
  shuffle=True,
  # callbacks=[model_checkpoint_callback]
)
# Out:
# Epoch 1/250
# 22/22 [==============================] - 7s 133ms/step - loss: 8.1761 - accuracy: 0.0299 - val_loss: 6.1252 - val_accuracy: 0.0238
# Epoch 2/250
# 22/22 [==============================] - 1s 36ms/step - loss: 5.1631 - accuracy: 0.0261 - val_loss: 4.4762 - val_accuracy: 0.0247
# Epoch 3/250
# 22/22 [==============================] - 1s 36ms/step - loss: 4.1812 - accuracy: 0.0386 - val_loss: 3.9596 - val_accuracy: 0.0494
# Epoch 4/250
# 22/22 [==============================] - 1s 36ms/step - loss: 3.8550 - accuracy: 0.0473 - val_loss: 3.7696 - val_accuracy: 0.0411
# Epoch 5/250
# 22/22 [==============================] - 1s 35ms/step - loss: 3.7249 - accuracy: 0.0640 - val_loss: 3.6732 - val_accuracy: 0.0430
# Epoch 6/250
# 22/22 [==============================] - 1s 32ms/step - loss: 3.5742 - accuracy: 0.0677 - val_loss: 3.4788 - val_accuracy: 0.0567
# Epoch 7/250
# 22/22 [==============================] - 1s 33ms/step - loss: 3.4637 - accuracy: 0.0766 - val_loss: 3.3724 - val_accuracy: 0.0941
# Epoch 8/250
# 22/22 [==============================] - 1s 33ms/step - loss: 3.3869 - accuracy: 0.0848 - val_loss: 3.3561 - val_accuracy: 0.0704
# Epoch 9/250
# 22/22 [==============================] - 1s 32ms/step - loss: 3.3004 - accuracy: 0.0983 - val_loss: 3.2160 - val_accuracy: 0.0978
# Epoch 10/250
# 22/22 [==============================] - 1s 32ms/step - loss: 3.2385 - accuracy: 0.1052 - val_loss: 3.1676 - val_accuracy: 0.1316
# Epoch 11/250
# 22/22 [==============================] - 1s 32ms/step - loss: 3.1628 - accuracy: 0.1335 - val_loss: 3.1833 - val_accuracy: 0.1316
# Epoch 12/250
# 22/22 [==============================] - 1s 32ms/step - loss: 3.0634 - accuracy: 0.1733 - val_loss: 2.9041 - val_accuracy: 0.1792
# Epoch 13/250
# 22/22 [==============================] - 1s 33ms/step - loss: 2.8358 - accuracy: 0.2266 - val_loss: 2.6963 - val_accuracy: 0.2541
# Epoch 14/250
# 22/22 [==============================] - 1s 32ms/step - loss: 2.7025 - accuracy: 0.2547 - val_loss: 2.5454 - val_accuracy: 0.3190
# Epoch 15/250
# 22/22 [==============================] - 1s 32ms/step - loss: 2.5650 - accuracy: 0.2958 - val_loss: 2.5731 - val_accuracy: 0.2751
# Epoch 16/250
# 22/22 [==============================] - 1s 32ms/step - loss: 2.5064 - accuracy: 0.3256 - val_loss: 2.3570 - val_accuracy: 0.3611
# Epoch 17/250
# 22/22 [==============================] - 1s 33ms/step - loss: 2.3752 - accuracy: 0.3676 - val_loss: 2.2157 - val_accuracy: 0.4186
# Epoch 18/250
# 22/22 [==============================] - 1s 34ms/step - loss: 2.2727 - accuracy: 0.4028 - val_loss: 2.2601 - val_accuracy: 0.4077
# Epoch 19/250
# 22/22 [==============================] - 1s 32ms/step - loss: 2.1862 - accuracy: 0.4227 - val_loss: 2.0529 - val_accuracy: 0.4479
# Epoch 20/250
# 22/22 [==============================] - 1s 33ms/step - loss: 2.1484 - accuracy: 0.4289 - val_loss: 2.1346 - val_accuracy: 0.4360
# Epoch 21/250
# 22/22 [==============================] - 1s 32ms/step - loss: 2.0938 - accuracy: 0.4522 - val_loss: 1.9921 - val_accuracy: 0.4909
# Epoch 22/250
# 22/22 [==============================] - 1s 33ms/step - loss: 2.0226 - accuracy: 0.4806 - val_loss: 1.9230 - val_accuracy: 0.5210
# Epoch 23/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.9612 - accuracy: 0.4801 - val_loss: 1.8546 - val_accuracy: 0.5366
# Epoch 24/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.9277 - accuracy: 0.5009 - val_loss: 1.9344 - val_accuracy: 0.5055
# Epoch 25/250
# 22/22 [==============================] - 1s 32ms/step - loss: 1.9094 - accuracy: 0.5114 - val_loss: 1.8510 - val_accuracy: 0.5119
# Epoch 26/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.9028 - accuracy: 0.5149 - val_loss: 1.8606 - val_accuracy: 0.5356
# Epoch 27/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.8114 - accuracy: 0.5421 - val_loss: 1.7871 - val_accuracy: 0.5430
# Epoch 28/250
# 22/22 [==============================] - 1s 32ms/step - loss: 1.8268 - accuracy: 0.5428 - val_loss: 1.8458 - val_accuracy: 0.5356
# Epoch 29/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.8165 - accuracy: 0.5482 - val_loss: 1.8905 - val_accuracy: 0.5219
# Epoch 30/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.7625 - accuracy: 0.5519 - val_loss: 1.7352 - val_accuracy: 0.5978
# Epoch 31/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.6733 - accuracy: 0.5830 - val_loss: 1.6523 - val_accuracy: 0.6170
# Epoch 32/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.6689 - accuracy: 0.5871 - val_loss: 1.6780 - val_accuracy: 0.6060
# Epoch 33/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.6217 - accuracy: 0.6054 - val_loss: 1.6697 - val_accuracy: 0.6015
# Epoch 34/250
# 22/22 [==============================] - 1s 32ms/step - loss: 1.6226 - accuracy: 0.6043 - val_loss: 1.6306 - val_accuracy: 0.6097
# Epoch 35/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.6139 - accuracy: 0.6132 - val_loss: 1.7888 - val_accuracy: 0.5686
# Epoch 36/250
# 22/22 [==============================] - 1s 32ms/step - loss: 1.6303 - accuracy: 0.6068 - val_loss: 1.7245 - val_accuracy: 0.6042
# Epoch 37/250
# 22/22 [==============================] - 1s 32ms/step - loss: 1.5982 - accuracy: 0.6150 - val_loss: 1.6009 - val_accuracy: 0.6609
# Epoch 38/250
# 22/22 [==============================] - 1s 32ms/step - loss: 1.5431 - accuracy: 0.6319 - val_loss: 1.6010 - val_accuracy: 0.6170
# Epoch 39/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.5319 - accuracy: 0.6454 - val_loss: 1.5610 - val_accuracy: 0.6581
# Epoch 40/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.5244 - accuracy: 0.6484 - val_loss: 1.5207 - val_accuracy: 0.6426
# Epoch 41/250
# 22/22 [==============================] - 1s 32ms/step - loss: 1.4455 - accuracy: 0.6692 - val_loss: 1.4935 - val_accuracy: 0.6664
# Epoch 42/250
# 22/22 [==============================] - 1s 33ms/step - loss: 1.4613 - accuracy: 0.6660 - val_loss: 1.5013 - val_accuracy: 0.6554
# Epoch 43/250
# 22/22 [==============================] - 1s 36ms/step - loss: 1.4563 - accuracy: 0.6685 - val_loss: 1.4850 - val_accuracy: 0.6664
# Epoch 44/250
# 22/22 [==============================] - 1s 36ms/step - loss: 1.4422 - accuracy: 0.6829 - val_loss: 1.4999 - val_accuracy: 0.6718
# Epoch 45/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.4457 - accuracy: 0.6744 - val_loss: 1.4837 - val_accuracy: 0.6728
# Epoch 46/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.4409 - accuracy: 0.6754 - val_loss: 1.4817 - val_accuracy: 0.6810
# Epoch 47/250
# 22/22 [==============================] - 1s 36ms/step - loss: 1.4607 - accuracy: 0.6731 - val_loss: 1.6057 - val_accuracy: 0.6243
# Epoch 48/250
# 22/22 [==============================] - 1s 36ms/step - loss: 1.4062 - accuracy: 0.6932 - val_loss: 1.4295 - val_accuracy: 0.6984
# Epoch 49/250
# 22/22 [==============================] - 1s 36ms/step - loss: 1.4232 - accuracy: 0.6836 - val_loss: 1.4945 - val_accuracy: 0.6801
# Epoch 50/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.3578 - accuracy: 0.7099 - val_loss: 1.4360 - val_accuracy: 0.7066
# Epoch 51/250
# 22/22 [==============================] - 1s 38ms/step - loss: 1.3473 - accuracy: 0.7085 - val_loss: 1.4264 - val_accuracy: 0.7157
# Epoch 52/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.3559 - accuracy: 0.7076 - val_loss: 1.4869 - val_accuracy: 0.6846
# Epoch 53/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.3712 - accuracy: 0.7028 - val_loss: 1.4450 - val_accuracy: 0.6947
# Epoch 54/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.3163 - accuracy: 0.7270 - val_loss: 1.4084 - val_accuracy: 0.7093
# Epoch 55/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.3227 - accuracy: 0.7268 - val_loss: 1.4461 - val_accuracy: 0.7057
# Epoch 56/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2601 - accuracy: 0.7369 - val_loss: 1.3577 - val_accuracy: 0.7212
# Epoch 57/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2766 - accuracy: 0.7348 - val_loss: 1.3629 - val_accuracy: 0.7294
# Epoch 58/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2542 - accuracy: 0.7421 - val_loss: 1.3960 - val_accuracy: 0.7148
# Epoch 59/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2489 - accuracy: 0.7474 - val_loss: 1.3638 - val_accuracy: 0.7230
# Epoch 60/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2469 - accuracy: 0.7412 - val_loss: 1.3825 - val_accuracy: 0.7130
# Epoch 61/250
# 22/22 [==============================] - 1s 36ms/step - loss: 1.2046 - accuracy: 0.7618 - val_loss: 1.3550 - val_accuracy: 0.7377
# Epoch 62/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2262 - accuracy: 0.7524 - val_loss: 1.3691 - val_accuracy: 0.7358
# Epoch 63/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2262 - accuracy: 0.7471 - val_loss: 1.3190 - val_accuracy: 0.7422
# Epoch 64/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2157 - accuracy: 0.7567 - val_loss: 1.3320 - val_accuracy: 0.7340
# Epoch 65/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2158 - accuracy: 0.7627 - val_loss: 1.3010 - val_accuracy: 0.7523
# Epoch 66/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.2153 - accuracy: 0.7666 - val_loss: 1.2954 - val_accuracy: 0.7450
# Epoch 67/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1712 - accuracy: 0.7796 - val_loss: 1.2952 - val_accuracy: 0.7532
# Epoch 68/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1681 - accuracy: 0.7764 - val_loss: 1.2917 - val_accuracy: 0.7633
# Epoch 69/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1759 - accuracy: 0.7725 - val_loss: 1.3086 - val_accuracy: 0.7532
# Epoch 70/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1992 - accuracy: 0.7657 - val_loss: 1.2874 - val_accuracy: 0.7569
# Epoch 71/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1397 - accuracy: 0.7890 - val_loss: 1.3250 - val_accuracy: 0.7587
# Epoch 72/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1586 - accuracy: 0.7775 - val_loss: 1.3205 - val_accuracy: 0.7303
# Epoch 73/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1542 - accuracy: 0.7805 - val_loss: 1.3291 - val_accuracy: 0.7541
# Epoch 74/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1548 - accuracy: 0.7785 - val_loss: 1.3003 - val_accuracy: 0.7569
# Epoch 75/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1223 - accuracy: 0.7936 - val_loss: 1.3072 - val_accuracy: 0.7596
# Epoch 76/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1324 - accuracy: 0.7908 - val_loss: 1.2664 - val_accuracy: 0.7623
# Epoch 77/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1049 - accuracy: 0.8002 - val_loss: 1.2735 - val_accuracy: 0.7687
# Epoch 78/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1099 - accuracy: 0.8000 - val_loss: 1.2952 - val_accuracy: 0.7605
# Epoch 79/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1066 - accuracy: 0.7938 - val_loss: 1.2383 - val_accuracy: 0.7651
# Epoch 80/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0885 - accuracy: 0.8013 - val_loss: 1.2693 - val_accuracy: 0.7715
# Epoch 81/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1101 - accuracy: 0.8022 - val_loss: 1.2152 - val_accuracy: 0.7879
# Epoch 82/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0852 - accuracy: 0.8073 - val_loss: 1.2509 - val_accuracy: 0.7623
# Epoch 83/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0995 - accuracy: 0.7993 - val_loss: 1.2820 - val_accuracy: 0.7523
# Epoch 84/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0620 - accuracy: 0.8125 - val_loss: 1.2959 - val_accuracy: 0.7669
# Epoch 85/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0732 - accuracy: 0.8121 - val_loss: 1.2300 - val_accuracy: 0.7797
# Epoch 86/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0748 - accuracy: 0.8148 - val_loss: 1.3064 - val_accuracy: 0.7706
# Epoch 87/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.1004 - accuracy: 0.7995 - val_loss: 1.3152 - val_accuracy: 0.7505
# Epoch 88/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0466 - accuracy: 0.8214 - val_loss: 1.2385 - val_accuracy: 0.7587
# Epoch 89/250
# 22/22 [==============================] - 1s 36ms/step - loss: 1.0660 - accuracy: 0.8128 - val_loss: 1.2705 - val_accuracy: 0.7669
# Epoch 90/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0535 - accuracy: 0.8198 - val_loss: 1.2794 - val_accuracy: 0.7651
# Epoch 91/250
# 22/22 [==============================] - 1s 36ms/step - loss: 1.0271 - accuracy: 0.8240 - val_loss: 1.2181 - val_accuracy: 0.7852
# Epoch 92/250
# 22/22 [==============================] - 1s 36ms/step - loss: 1.0723 - accuracy: 0.8134 - val_loss: 1.2026 - val_accuracy: 0.8026
# Epoch 93/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0454 - accuracy: 0.8246 - val_loss: 1.2303 - val_accuracy: 0.7888
# Epoch 94/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0232 - accuracy: 0.8240 - val_loss: 1.2525 - val_accuracy: 0.7751
# Epoch 95/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0338 - accuracy: 0.8272 - val_loss: 1.2099 - val_accuracy: 0.7861
# Epoch 96/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0321 - accuracy: 0.8251 - val_loss: 1.2416 - val_accuracy: 0.7733
# Epoch 97/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0557 - accuracy: 0.8256 - val_loss: 1.3135 - val_accuracy: 0.7486
# Epoch 98/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0162 - accuracy: 0.8301 - val_loss: 1.1942 - val_accuracy: 0.7916
# Epoch 99/250
# 22/22 [==============================] - 1s 37ms/step - loss: 1.0127 - accuracy: 0.8336 - val_loss: 1.2143 - val_accuracy: 0.7852
# Epoch 100/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9979 - accuracy: 0.8356 - val_loss: 1.2398 - val_accuracy: 0.7742
# Epoch 101/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9869 - accuracy: 0.8388 - val_loss: 1.2069 - val_accuracy: 0.7824
# Epoch 102/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9932 - accuracy: 0.8356 - val_loss: 1.1846 - val_accuracy: 0.7980
# Epoch 103/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9884 - accuracy: 0.8409 - val_loss: 1.1649 - val_accuracy: 0.7998
# Epoch 104/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.9986 - accuracy: 0.8365 - val_loss: 1.1794 - val_accuracy: 0.7980
# Epoch 105/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9995 - accuracy: 0.8356 - val_loss: 1.1867 - val_accuracy: 0.7916
# Epoch 106/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9577 - accuracy: 0.8551 - val_loss: 1.1923 - val_accuracy: 0.7980
# Epoch 107/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9504 - accuracy: 0.8601 - val_loss: 1.2103 - val_accuracy: 0.7971
# Epoch 108/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9812 - accuracy: 0.8374 - val_loss: 1.1572 - val_accuracy: 0.8035
# Epoch 109/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9824 - accuracy: 0.8395 - val_loss: 1.2653 - val_accuracy: 0.7642
# Epoch 110/250
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9784 - accuracy: 0.8402 - val_loss: 1.1836 - val_accuracy: 0.7916
# Epoch 111/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9685 - accuracy: 0.8374 - val_loss: 1.1653 - val_accuracy: 0.8026
# Epoch 112/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9836 - accuracy: 0.8429 - val_loss: 1.2147 - val_accuracy: 0.7797
# Epoch 113/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9952 - accuracy: 0.8386 - val_loss: 1.2722 - val_accuracy: 0.7751
# Epoch 114/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9644 - accuracy: 0.8480 - val_loss: 1.1533 - val_accuracy: 0.7980
# Epoch 115/250
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9691 - accuracy: 0.8532 - val_loss: 1.1429 - val_accuracy: 0.8044
# Epoch 116/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.9462 - accuracy: 0.8551 - val_loss: 1.1926 - val_accuracy: 0.7824
# Epoch 117/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9408 - accuracy: 0.8553 - val_loss: 1.1485 - val_accuracy: 0.8007
# Epoch 118/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9123 - accuracy: 0.8605 - val_loss: 1.1435 - val_accuracy: 0.8117
# Epoch 119/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9549 - accuracy: 0.8505 - val_loss: 1.2249 - val_accuracy: 0.7751
# Epoch 120/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.9479 - accuracy: 0.8557 - val_loss: 1.2211 - val_accuracy: 0.7761
# Epoch 121/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9454 - accuracy: 0.8487 - val_loss: 1.2116 - val_accuracy: 0.7989
# Epoch 122/250
# 22/22 [==============================] - 1s 39ms/step - loss: 0.9509 - accuracy: 0.8564 - val_loss: 1.1696 - val_accuracy: 0.8016
# Epoch 123/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9315 - accuracy: 0.8578 - val_loss: 1.1227 - val_accuracy: 0.7971
# Epoch 124/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.9266 - accuracy: 0.8601 - val_loss: 1.1625 - val_accuracy: 0.7998
# Epoch 125/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.9568 - accuracy: 0.8505 - val_loss: 1.1397 - val_accuracy: 0.7971
# Epoch 126/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.9102 - accuracy: 0.8658 - val_loss: 1.1075 - val_accuracy: 0.8172
# Epoch 127/250
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9090 - accuracy: 0.8612 - val_loss: 1.1820 - val_accuracy: 0.7925
# Epoch 128/250
# 22/22 [==============================] - 1s 38ms/step - loss: 0.9310 - accuracy: 0.8594 - val_loss: 1.1651 - val_accuracy: 0.7980
# Epoch 129/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.9043 - accuracy: 0.8672 - val_loss: 1.2043 - val_accuracy: 0.7916
# Epoch 130/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.8987 - accuracy: 0.8692 - val_loss: 1.1591 - val_accuracy: 0.8016
# Epoch 131/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.9142 - accuracy: 0.8612 - val_loss: 1.1295 - val_accuracy: 0.8053
# Epoch 132/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8994 - accuracy: 0.8706 - val_loss: 1.1640 - val_accuracy: 0.8035
# Epoch 133/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8858 - accuracy: 0.8749 - val_loss: 1.1336 - val_accuracy: 0.7952
# Epoch 134/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8954 - accuracy: 0.8665 - val_loss: 1.1955 - val_accuracy: 0.7952
# Epoch 135/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8940 - accuracy: 0.8672 - val_loss: 1.1515 - val_accuracy: 0.8062
# Epoch 136/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8791 - accuracy: 0.8727 - val_loss: 1.1206 - val_accuracy: 0.8181
# Epoch 137/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8907 - accuracy: 0.8663 - val_loss: 1.1500 - val_accuracy: 0.8053
# Epoch 138/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8917 - accuracy: 0.8724 - val_loss: 1.1549 - val_accuracy: 0.8007
# Epoch 139/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8812 - accuracy: 0.8733 - val_loss: 1.1418 - val_accuracy: 0.8090
# Epoch 140/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8711 - accuracy: 0.8800 - val_loss: 1.1667 - val_accuracy: 0.8016
# Epoch 141/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8667 - accuracy: 0.8795 - val_loss: 1.1216 - val_accuracy: 0.8154
# Epoch 142/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8733 - accuracy: 0.8795 - val_loss: 1.1328 - val_accuracy: 0.8062
# Epoch 143/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8666 - accuracy: 0.8779 - val_loss: 1.1792 - val_accuracy: 0.7879
# Epoch 144/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8803 - accuracy: 0.8717 - val_loss: 1.1418 - val_accuracy: 0.8080
# Epoch 145/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8949 - accuracy: 0.8653 - val_loss: 1.1642 - val_accuracy: 0.7989
# Epoch 146/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8759 - accuracy: 0.8797 - val_loss: 1.1811 - val_accuracy: 0.8044
# Epoch 147/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8884 - accuracy: 0.8692 - val_loss: 1.1680 - val_accuracy: 0.7916
# Epoch 148/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8523 - accuracy: 0.8880 - val_loss: 1.1183 - val_accuracy: 0.8144
# Epoch 149/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8666 - accuracy: 0.8752 - val_loss: 1.1782 - val_accuracy: 0.7934
# Epoch 150/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8350 - accuracy: 0.8898 - val_loss: 1.1371 - val_accuracy: 0.8053
# Epoch 151/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8520 - accuracy: 0.8841 - val_loss: 1.1093 - val_accuracy: 0.8245
# Epoch 152/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8646 - accuracy: 0.8717 - val_loss: 1.1539 - val_accuracy: 0.7998
# Epoch 153/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8933 - accuracy: 0.8699 - val_loss: 1.1701 - val_accuracy: 0.7888
# Epoch 154/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8559 - accuracy: 0.8813 - val_loss: 1.1060 - val_accuracy: 0.8117
# Epoch 155/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8859 - accuracy: 0.8768 - val_loss: 1.2832 - val_accuracy: 0.7724
# Epoch 156/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.9093 - accuracy: 0.8745 - val_loss: 1.1547 - val_accuracy: 0.8007
# Epoch 157/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8415 - accuracy: 0.8880 - val_loss: 1.1672 - val_accuracy: 0.8117
# Epoch 158/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8482 - accuracy: 0.8834 - val_loss: 1.0977 - val_accuracy: 0.8227
# Epoch 159/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8376 - accuracy: 0.8859 - val_loss: 1.1346 - val_accuracy: 0.8117
# Epoch 160/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8342 - accuracy: 0.8871 - val_loss: 1.0965 - val_accuracy: 0.8236
# Epoch 161/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8551 - accuracy: 0.8827 - val_loss: 1.1201 - val_accuracy: 0.8035
# Epoch 162/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8588 - accuracy: 0.8807 - val_loss: 1.1174 - val_accuracy: 0.8172
# Epoch 163/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8335 - accuracy: 0.8948 - val_loss: 1.1067 - val_accuracy: 0.8190
# Epoch 164/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8684 - accuracy: 0.8779 - val_loss: 1.1398 - val_accuracy: 0.7998
# Epoch 165/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8588 - accuracy: 0.8829 - val_loss: 1.1267 - val_accuracy: 0.8199
# Epoch 166/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8349 - accuracy: 0.8912 - val_loss: 1.1418 - val_accuracy: 0.8044
# Epoch 167/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8339 - accuracy: 0.8930 - val_loss: 1.1307 - val_accuracy: 0.8062
# Epoch 168/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8451 - accuracy: 0.8800 - val_loss: 1.1313 - val_accuracy: 0.8080
# Epoch 169/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8424 - accuracy: 0.8905 - val_loss: 1.2093 - val_accuracy: 0.7852
# Epoch 170/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8504 - accuracy: 0.8804 - val_loss: 1.1212 - val_accuracy: 0.8090
# Epoch 171/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8527 - accuracy: 0.8834 - val_loss: 1.1292 - val_accuracy: 0.8199
# Epoch 172/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8352 - accuracy: 0.8932 - val_loss: 1.1158 - val_accuracy: 0.8117
# Epoch 173/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8215 - accuracy: 0.8916 - val_loss: 1.1053 - val_accuracy: 0.8236
# Epoch 174/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8080 - accuracy: 0.8955 - val_loss: 1.1415 - val_accuracy: 0.8016
# Epoch 175/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8252 - accuracy: 0.8905 - val_loss: 1.1473 - val_accuracy: 0.8016
# Epoch 176/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8118 - accuracy: 0.8941 - val_loss: 1.1139 - val_accuracy: 0.8071
# Epoch 177/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8050 - accuracy: 0.8971 - val_loss: 1.1252 - val_accuracy: 0.8126
# Epoch 178/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.8263 - accuracy: 0.8960 - val_loss: 1.1461 - val_accuracy: 0.7980
# Epoch 179/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8361 - accuracy: 0.8857 - val_loss: 1.1166 - val_accuracy: 0.8190
# Epoch 180/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8296 - accuracy: 0.8893 - val_loss: 1.1278 - val_accuracy: 0.8044
# Epoch 181/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8186 - accuracy: 0.8896 - val_loss: 1.0887 - val_accuracy: 0.8218
# Epoch 182/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8222 - accuracy: 0.8880 - val_loss: 1.0816 - val_accuracy: 0.8208
# Epoch 183/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8294 - accuracy: 0.8873 - val_loss: 1.1150 - val_accuracy: 0.8108
# Epoch 184/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.8114 - accuracy: 0.8944 - val_loss: 1.0624 - val_accuracy: 0.8263
# Epoch 185/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.7994 - accuracy: 0.9042 - val_loss: 1.1229 - val_accuracy: 0.8016
# Epoch 186/250
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8293 - accuracy: 0.8930 - val_loss: 1.1131 - val_accuracy: 0.8080
# Epoch 187/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.8043 - accuracy: 0.8948 - val_loss: 1.0958 - val_accuracy: 0.8163
# Epoch 188/250
# 22/22 [==============================] - 1s 39ms/step - loss: 0.8151 - accuracy: 0.8916 - val_loss: 1.0930 - val_accuracy: 0.8163
# Epoch 189/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.8510 - accuracy: 0.8743 - val_loss: 1.1508 - val_accuracy: 0.7952
# Epoch 190/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.8262 - accuracy: 0.8896 - val_loss: 1.1221 - val_accuracy: 0.8172
# Epoch 191/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8169 - accuracy: 0.8932 - val_loss: 1.0896 - val_accuracy: 0.8163
# Epoch 192/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7685 - accuracy: 0.9099 - val_loss: 1.0894 - val_accuracy: 0.8254
# Epoch 193/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.8177 - accuracy: 0.8948 - val_loss: 1.0569 - val_accuracy: 0.8355
# Epoch 194/250
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7905 - accuracy: 0.9003 - val_loss: 1.0877 - val_accuracy: 0.8181
# Epoch 195/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.8180 - accuracy: 0.8909 - val_loss: 1.0667 - val_accuracy: 0.8181
# Epoch 196/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.8102 - accuracy: 0.8985 - val_loss: 1.0931 - val_accuracy: 0.8254
# Epoch 197/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.8057 - accuracy: 0.8960 - val_loss: 1.1058 - val_accuracy: 0.8154
# Epoch 198/250
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7847 - accuracy: 0.9049 - val_loss: 1.1114 - val_accuracy: 0.8117
# Epoch 199/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.8074 - accuracy: 0.8921 - val_loss: 1.1177 - val_accuracy: 0.8126
# Epoch 200/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.8496 - accuracy: 0.8825 - val_loss: 1.0989 - val_accuracy: 0.8108
# Epoch 201/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.8176 - accuracy: 0.8916 - val_loss: 1.0981 - val_accuracy: 0.8163
# Epoch 202/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7960 - accuracy: 0.9028 - val_loss: 1.1050 - val_accuracy: 0.8227
# Epoch 203/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7832 - accuracy: 0.9031 - val_loss: 1.0625 - val_accuracy: 0.8199
# Epoch 204/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.8063 - accuracy: 0.8939 - val_loss: 1.1019 - val_accuracy: 0.8090
# Epoch 205/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.8043 - accuracy: 0.9010 - val_loss: 1.0899 - val_accuracy: 0.8282
# Epoch 206/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7926 - accuracy: 0.9005 - val_loss: 1.1413 - val_accuracy: 0.8053
# Epoch 207/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.8112 - accuracy: 0.8978 - val_loss: 1.1028 - val_accuracy: 0.8144
# Epoch 208/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.8023 - accuracy: 0.8967 - val_loss: 1.0962 - val_accuracy: 0.8135
# Epoch 209/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7862 - accuracy: 0.9031 - val_loss: 1.1216 - val_accuracy: 0.8090
# Epoch 210/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7899 - accuracy: 0.8976 - val_loss: 1.0928 - val_accuracy: 0.8135
# Epoch 211/250
# 22/22 [==============================] - 1s 39ms/step - loss: 0.7798 - accuracy: 0.9058 - val_loss: 1.0843 - val_accuracy: 0.8227
# Epoch 212/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7762 - accuracy: 0.9019 - val_loss: 1.1772 - val_accuracy: 0.7952
# Epoch 213/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.8015 - accuracy: 0.8925 - val_loss: 1.1509 - val_accuracy: 0.8108
# Epoch 214/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.7825 - accuracy: 0.9065 - val_loss: 1.1085 - val_accuracy: 0.8144
# Epoch 215/250
# 22/22 [==============================] - 1s 34ms/step - loss: 0.7942 - accuracy: 0.8971 - val_loss: 1.1122 - val_accuracy: 0.8163
# Epoch 216/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7857 - accuracy: 0.9017 - val_loss: 1.1118 - val_accuracy: 0.8236
# Epoch 217/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.8000 - accuracy: 0.8964 - val_loss: 1.0879 - val_accuracy: 0.8263
# Epoch 218/250
# 22/22 [==============================] - 1s 38ms/step - loss: 0.8162 - accuracy: 0.8923 - val_loss: 1.1034 - val_accuracy: 0.8245
# Epoch 219/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.7957 - accuracy: 0.9028 - val_loss: 1.0645 - val_accuracy: 0.8108
# Epoch 220/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.7881 - accuracy: 0.8999 - val_loss: 1.0542 - val_accuracy: 0.8309
# Epoch 221/250
# 22/22 [==============================] - 1s 39ms/step - loss: 0.7562 - accuracy: 0.9111 - val_loss: 1.0644 - val_accuracy: 0.8245
# Epoch 222/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7740 - accuracy: 0.9037 - val_loss: 1.1105 - val_accuracy: 0.8026
# Epoch 223/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.7950 - accuracy: 0.9005 - val_loss: 1.0433 - val_accuracy: 0.8355
# Epoch 224/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7828 - accuracy: 0.9040 - val_loss: 1.0439 - val_accuracy: 0.8355
# Epoch 225/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7869 - accuracy: 0.9081 - val_loss: 1.0534 - val_accuracy: 0.8327
# Epoch 226/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7687 - accuracy: 0.9097 - val_loss: 1.0854 - val_accuracy: 0.8163
# Epoch 227/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7696 - accuracy: 0.9079 - val_loss: 1.0445 - val_accuracy: 0.8373
# Epoch 228/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7515 - accuracy: 0.9097 - val_loss: 1.0411 - val_accuracy: 0.8336
# Epoch 229/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.7615 - accuracy: 0.9115 - val_loss: 1.0455 - val_accuracy: 0.8373
# Epoch 230/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.7422 - accuracy: 0.9118 - val_loss: 1.0788 - val_accuracy: 0.8364
# Epoch 231/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.7966 - accuracy: 0.8939 - val_loss: 1.1420 - val_accuracy: 0.8135
# Epoch 232/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.7953 - accuracy: 0.8960 - val_loss: 1.1159 - val_accuracy: 0.8309
# Epoch 233/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7603 - accuracy: 0.9131 - val_loss: 1.0739 - val_accuracy: 0.8254
# Epoch 234/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7837 - accuracy: 0.9031 - val_loss: 1.1486 - val_accuracy: 0.7888
# Epoch 235/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7818 - accuracy: 0.8999 - val_loss: 1.0634 - val_accuracy: 0.8400
# Epoch 236/250
# 22/22 [==============================] - 1s 35ms/step - loss: 0.7599 - accuracy: 0.9118 - val_loss: 1.0464 - val_accuracy: 0.8300
# Epoch 237/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7348 - accuracy: 0.9179 - val_loss: 1.0659 - val_accuracy: 0.8291
# Epoch 238/250
# 22/22 [==============================] - 1s 38ms/step - loss: 0.7333 - accuracy: 0.9179 - val_loss: 1.0656 - val_accuracy: 0.8181
# Epoch 239/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7522 - accuracy: 0.9106 - val_loss: 1.0782 - val_accuracy: 0.8300
# Epoch 240/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7564 - accuracy: 0.9134 - val_loss: 1.0950 - val_accuracy: 0.8199
# Epoch 241/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7582 - accuracy: 0.9076 - val_loss: 1.0922 - val_accuracy: 0.8190
# Epoch 242/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7555 - accuracy: 0.9113 - val_loss: 1.0833 - val_accuracy: 0.8263
# Epoch 243/250
# 22/22 [==============================] - 1s 37ms/step - loss: 0.7524 - accuracy: 0.9124 - val_loss: 1.0950 - val_accuracy: 0.8208
# Epoch 244/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7616 - accuracy: 0.9090 - val_loss: 1.0594 - val_accuracy: 0.8236
# Epoch 245/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7525 - accuracy: 0.9115 - val_loss: 1.1489 - val_accuracy: 0.8035
# Epoch 246/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7584 - accuracy: 0.9113 - val_loss: 1.0423 - val_accuracy: 0.8272
# Epoch 247/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7377 - accuracy: 0.9172 - val_loss: 1.0579 - val_accuracy: 0.8218
# Epoch 248/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7487 - accuracy: 0.9159 - val_loss: 1.0662 - val_accuracy: 0.8263
# Epoch 249/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7652 - accuracy: 0.9003 - val_loss: 1.0821 - val_accuracy: 0.8144
# Epoch 250/250
# 22/22 [==============================] - 1s 36ms/step - loss: 0.7748 - accuracy: 0.8964 - val_loss: 1.1145 - val_accuracy: 0.8099
# CPU times: total: 4min 23s
# Wall time: 3min 21s

# %%
# model.load_weights("models/checkpoints/famous48_test_model_v2_best.keras")
model.evaluate(X_test, y_test_fixed)
# Out:
# 43/43 [==============================] - 1s 9ms/step - loss: 1.1375 - accuracy: 0.7996
# [1.1374937295913696, 0.799561083316803]

# %%
length = len(history.history['accuracy'])
print("train set accuracy:", round(history.history['accuracy'][length-1], 3))
print("train loss:", round(history.history['loss'][length-1], 3))
print("validation set accuracy:", round(history.history['val_accuracy'][length-1], 3))
print("validation set loss:", round(history.history['val_loss'][length-1], 3))
# Out:
# train set accuracy: 0.896
# train loss: 0.775
# validation set accuracy: 0.81
# validation set loss: 1.115

# %%
results = model.evaluate(X_test, y_test_fixed)
print("test set accuracy:", round(results[1], 3))
print("test set loss:", round(results[0], 3))
# Out:
# 43/43 [==============================] - 1s 5ms/step - loss: 1.1375 - accuracy: 0.7996
# test set accuracy: 0.8
# test set loss: 1.137

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(16, 10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
